# %% [markdown]
# <a href="https://colab.research.google.com/github/omkarande2525/ML-Pracs/blob/main/OM_ASSIGNMENT3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ASSIGNMENT 3**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-d79ed788-757e-4241-9107-bb32e81a2cd2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d79ed788-757e-4241-9107-bb32e81a2cd2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("Iris.csv")

# %%
for species in df['Species'].unique():
    subset = df[df['Species'] == species]
    plt.scatter(
        subset['SepalLengthCm'],
        subset['PetalLengthCm'],
        label=species
    )

plt.xlabel("Sepal Length (cm)")
plt.ylabel("Petal Length (cm)")
plt.title("Scatter Plot: Sepal Length vs Petal Length")
plt.legend()
plt.show()

# %%
species_count = df['Species'].value_counts()

plt.bar(
    species_count.index,
    species_count.values,
    label="Number of Samples"
)

plt.xlabel("Species")
plt.ylabel("Count")
plt.title("Bar Plot: Species Count")
plt.legend()
plt.show()

# %%
data = [
    df['SepalLengthCm'],
    df['SepalWidthCm'],
    df['PetalLengthCm'],
    df['PetalWidthCm']
]

plt.boxplot(
    data,
    labels=['Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width'],
    patch_artist=True
)

plt.title("Box Plot of Iris Features")
plt.ylabel("Value (cm)")
plt.show()
# Out:
# /tmp/ipython-input-4102965664.py:8: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(

# %%
colors = ['lightblue', 'lightgreen', 'lightcoral']

plt.pie(
    species_count.values,
    labels=species_count.index,
    autopct='%1.1f%%',
    colors=colors
)

plt.title("Pie Chart: Species Distribution")
plt.legend(
    species_count.index,
    title="Species",
    loc="upper right"
)
plt.show()

# %%
plt.plot(
    df['SepalLengthCm'],
    label="Sepal Length",
)

plt.plot(
    df['PetalLengthCm'],
    label="Petal Length",
)

plt.xlabel("Index")
plt.ylabel("Length (cm)")
plt.title("Line Chart: Sepal vs Petal Length")
plt.legend()
plt.show()
